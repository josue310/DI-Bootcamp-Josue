# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# 1. Importer
url = "datascience_salaries.csv"
df = pd.read_csv(url)

# 2. Normalisation
scaler = MinMaxScaler()
df['salary_normalized'] = scaler.fit_transform(df[['salary']])

# 3. PCA
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df[numerical_cols])
df['PCA_1'] = pca_result[:, 0]
df['PCA_2'] = pca_result[:, 1]

# 4. Agrégation
aggregation = df.groupby('experience_level')['salary'].agg(['mean', 'median'])
aggregation.columns = ['Salaire_Moyen', 'Salaire_Médian']
print(aggregation)
# Out:
#                   Salaire_Moyen  Salaire_Médian
# experience_level
# Entry              36111.111111         30000.0
# Executive          76076.923077         46000.0
# Mid                51786.885246         51000.0
# Senior             75088.033012         68000.0
